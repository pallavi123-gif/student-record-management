# %%
import pandas as pd
data1=pd.read_excel(r'C:\Python tidal\april2013.xls.xls')
data1.head()
# Out:
#                                                  Wave Data of Minicoy for 04/04/2013  \
# 0                                                NaN
# 1                                     Time(mmddhhmm)
# 2                                       04040020.4RW
# 3                                       04040120.4RW
# 4                                       04040220.4RW
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1     Data %      Waves       Hmax        Thm      H1/10      T1/10
# 2   99.96745        227         45   11.16264   37.99153   9.350759
# 3   99.96745        241         50   11.25544      38.12   10.37978
# 4   99.96745        213         50    11.3664   41.16216   9.821616
#
#   Unnamed: 7  Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN         NaN        NaN         NaN         NaN
# 1       H1/3        T1/3       Havg        Tavg         Eps
# ...

# %%
import pandas as pd
data1=pd.read_excel(r'C:\Python tidal\april2013.xls.xls',skiprows=2)
data1.head()
# Out:
#   Time(mmddhhmm)    Data %   Waves  Hmax       Thm     H1/10      T1/10  \
# 0   04040020.4RW  99.96745     227    45  11.16264  37.99153   9.350759
# 1   04040120.4RW  99.96745     241    50  11.25544  38.12000  10.379780
# 2   04040220.4RW  99.96745     213    50  11.36640  41.16216   9.821616
# 3   04040320.4RW  99.96745     226    52  12.96285  39.78724   9.937702
# 4   04040420.4RW  99.96745     193    65  12.11177  49.50495  11.167350
#
#        H1/3        T1/3      Havg        Tavg         Eps
# 0  30.27074    7.740685  19.64317    5.252430    0.842183
# 1  29.58025    8.047920  18.43568    4.999222    0.838274
# 2  32.56744    8.521933  20.55399    5.609682    0.863272
# 3  31.00000    7.967224  19.74779    5.272195    0.848451
# 4  37.10769    9.651505  22.15026    6.177589    0.876558

# %%
data1.shape
# Out:
# (24, 12)

# %%
data2=pd.read_excel(r"C:\Python tidal\june13.xls.xls",skiprows=2)
data2.head()
# Out:
#   Time(mmddhhmm)    Data %   Waves  Hmax        Thm     H1/10      T1/10  \
# 0   06010020.4RW  99.96745     199    87  12.390630  58.19231  10.224140
# 1   06010120.4RW  99.96745     197    73  13.604840  58.89321  10.435930
# 2   06010220.4RW  99.96745     248    78  11.652510  59.24903   9.931164
# 3   06010320.4RW  99.96745     247    80  12.754850  59.26563   8.666854
# 4   06010420.4RW  99.96745     248    69   8.828835  56.61478   7.901264
#
#        H1/3        T1/3      Havg        Tavg         Eps
# 0  46.23881    8.920895  28.46734    6.022895    0.853592
# 1  48.32161    9.125974  30.73096    6.110076    0.866025
# 2  46.37200    7.815660  28.59678    4.856486    0.856834
# 3  46.25301    6.850528  30.34008    4.823990    0.834281
# 4  45.69200    6.693411  30.27016    4.841084    0.796318

# %%
data2.shape
# Out:
# (24, 12)

# %%
data3=pd.read_excel(r'C:\Python tidal\mod on 09032013__april2013.xls',skiprows=2)
data3.head()
# Out:
#   Time(mmddhhmm)    Data %   Waves  Hmax       Thm     H1/10      T1/10  \
# 0   04010020.4RW  99.96745     192    72  11.91066  51.50747   10.90083
# 1   04010120.4RW  99.96745     180    77  10.09391  52.21164   11.41311
# 2   04010220.4RW  99.96745     157    77  12.25898  51.59036   11.35639
# 3   04010320.4RW  99.96745     161    66  11.87500  50.64706   11.09125
# 4   04010420.4RW  99.96745     168    63  11.68699  53.04520   11.29683
#
#        H1/3        T1/3      Havg        Tavg         Eps
# 0  40.31443    9.989961  23.65104    6.266510    0.881735
# 1  39.78022   10.434800  24.26111    6.643161    0.882680
# 2  41.54717   11.233200  25.43949    7.635776    0.919752
# 3  42.08589   10.699740  25.20497    7.385116    0.899794
# 4  41.74117   10.453160  23.97024    7.096348    0.874985

# %%
data3.shape
# Out:
# (24, 12)

# %%
data=pd.merge(data1,data2, how='outer')
data
# Out:
#    Time(mmddhhmm)    Data %   Waves  Hmax        Thm     H1/10      T1/10  \
# 0    04040020.4RW  99.96745     227    45  11.162640  37.99153   9.350759
# 1    04040120.4RW  99.96745     241    50  11.255440  38.12000  10.379780
# 2    04040220.4RW  99.96745     213    50  11.366400  41.16216   9.821616
# 3    04040320.4RW  99.96745     226    52  12.962850  39.78724   9.937702
# 4    04040420.4RW  99.96745     193    65  12.111770  49.50495  11.167350
# 5    04040520.4RW  99.96745     184    62  10.092570  45.08290  10.781290
# 6    04040620.4RW  99.96745     183    50  11.464910  41.34375  10.635350
# 7    04040720.4RW  99.96745     203    48  10.750950  35.71698  10.493560
# 8    04040820.4RW  99.96745     206    76  10.734420  50.34884  10.436780
# 9    04040920.4RW  99.96745     217    68  10.546880  46.49557  10.131550
# 10   04041020.4RW  99.96745     200    70  10.876160  54.00478  11.230010
# 11   04041120.4RW  99.96745     216    59  11.601200  46.51111  10.664270
# ...

# %%
data=data.merge(data3,how='outer')
data
# Out:
#    Time(mmddhhmm)    Data %   Waves  Hmax        Thm     H1/10      T1/10  \
# 0    04010020.4RW  99.96745     192    72  11.910660  51.50747  10.900830
# 1    04010120.4RW  99.96745     180    77  10.093910  52.21164  11.413110
# 2    04010220.4RW  99.96745     157    77  12.258980  51.59036  11.356390
# 3    04010320.4RW  99.96745     161    66  11.875000  50.64706  11.091250
# 4    04010420.4RW  99.96745     168    63  11.686990  53.04520  11.296830
# ..            ...       ...     ...   ...        ...       ...        ...
# 67   06011920.4RW  99.96745     181    89   8.937658  56.21053  10.314400
# 68   06012020.4RW  99.96745     189    78   9.834087  54.33333   9.774129
# 69   06012120.4RW  99.96745     170    77  11.329360  55.08380   9.969692
# 70   06012220.4RW  99.96745     176    71  10.767210  53.75676  10.424220
# 71   06012320.4RW  99.96745     198    89  11.262180  62.44928  10.062700
#
#         H1/3        T1/3      Havg        Tavg         Eps
# ...

# %%
import pandas as pd
data = pd.concat([data1, data2, data3], axis=0)
data.head()
# Out:
#   Time(mmddhhmm)    Data %   Waves  Hmax       Thm     H1/10      T1/10  \
# 0   04040020.4RW  99.96745     227    45  11.16264  37.99153   9.350759
# 1   04040120.4RW  99.96745     241    50  11.25544  38.12000  10.379780
# 2   04040220.4RW  99.96745     213    50  11.36640  41.16216   9.821616
# 3   04040320.4RW  99.96745     226    52  12.96285  39.78724   9.937702
# 4   04040420.4RW  99.96745     193    65  12.11177  49.50495  11.167350
#
#        H1/3        T1/3      Havg        Tavg         Eps
# 0  30.27074    7.740685  19.64317    5.252430    0.842183
# 1  29.58025    8.047920  18.43568    4.999222    0.838274
# 2  32.56744    8.521933  20.55399    5.609682    0.863272
# 3  31.00000    7.967224  19.74779    5.272195    0.848451
# 4  37.10769    9.651505  22.15026    6.177589    0.876558

# %%
data.shape
# Out:
# (72, 12)

# %%
data.isnull().sum()
# Out:
# Time(mmddhhmm)    0
# Data %            0
#  Waves            0
# Hmax              0
#     Thm           0
#    H1/10          0
#     T1/10         0
#   H1/3            0
#       T1/3        0
#   Havg            0
#       Tavg        0
#        Eps        0
# dtype: int64

# %%
data.describe()
# Out:
#          Data %       Waves       Hmax        Thm      H1/10      T1/10  \
# count  72.00000   72.000000  72.000000  72.000000  72.000000  72.000000
# mean   99.96745  197.388889  69.263889  11.052089  52.537206  10.374835
# std     0.00000   37.170545  10.548337   1.428801   6.682387   1.255907
# min    99.96745  137.000000  45.000000   4.661427  35.716980   5.088553
# 25%    99.96745  167.000000  63.000000  10.483455  49.342568   9.936068
# 50%    99.96745  195.500000  69.500000  11.258810  52.664440  10.610455
# 75%    99.96745  227.750000  77.000000  12.027595  56.537417  11.301405
# max    99.96745  307.000000  94.000000  13.604840  65.547940  11.810090
#
#             H1/3        T1/3       Havg        Tavg         Eps
# count  72.000000   72.000000  72.000000   72.000000   72.000000
# mean   41.291374    9.278067  25.360273    6.273400    0.870869
# std     5.239916    1.562467   3.323040    1.165073    0.041572
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 0 to 23
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time(mmddhhmm)  72 non-null     object
#  1   Data %          72 non-null     float64
#  2    Waves          72 non-null     int64
#  3   Hmax            72 non-null     int64
#  4       Thm         72 non-null     float64
#  5      H1/10        72 non-null     float64
#  6       T1/10       72 non-null     float64
#  7     H1/3          72 non-null     float64
#  8         T1/3      72 non-null     float64
#  9     Havg          72 non-null     float64
#  10        Tavg      72 non-null     float64
#  11         Eps      72 non-null     float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 7.3+ KB

# %%
data['Data %'].value_counts()
# Out:
# Data %
# 99.96745    72
# Name: count, dtype: int64

# %%
data=data.drop('Data %',axis=1)
data.head()
# Out:
#   Time(mmddhhmm)   Waves  Hmax       Thm     H1/10      T1/10      H1/3  \
# 0   04040020.4RW     227    45  11.16264  37.99153   9.350759  30.27074
# 1   04040120.4RW     241    50  11.25544  38.12000  10.379780  29.58025
# 2   04040220.4RW     213    50  11.36640  41.16216   9.821616  32.56744
# 3   04040320.4RW     226    52  12.96285  39.78724   9.937702  31.00000
# 4   04040420.4RW     193    65  12.11177  49.50495  11.167350  37.10769
#
#          T1/3      Havg        Tavg         Eps
# 0    7.740685  19.64317    5.252430    0.842183
# 1    8.047920  18.43568    4.999222    0.838274
# 2    8.521933  20.55399    5.609682    0.863272
# 3    7.967224  19.74779    5.272195    0.848451
# 4    9.651505  22.15026    6.177589    0.876558

# %%
data.columns=[i.strip() for i in data.columns]
data.columns
# Out:
# Index(['Time(mmddhhmm)', 'Waves', 'Hmax', 'Thm', 'H1/10', 'T1/10', 'H1/3',
#        'T1/3', 'Havg', 'Tavg', 'Eps'],
#       dtype='object')

# %%
data=data.rename(columns={'Time(mmddhhmm)':'Time(mddhhmm)'})

# %%
data.columns[0]
# Out:
# 'Time(mddhhmm)'

# %%
data['Time(mddhhmm)'][0][:8]
# Out:
# 0    04040020.4RW
# 0    06010020.4RW
# 0    04010020.4RW
# Name: Time(mddhhmm), dtype: object

# %%
data['Time(mddhhmm)'] = data['Time(mddhhmm)'].str[:8].astype(int)
data.head()
# Out:
#    Time(mddhhmm)  Waves  Hmax       Thm     H1/10      T1/10      H1/3  \
# 0        4040020    227    45  11.16264  37.99153   9.350759  30.27074
# 1        4040120    241    50  11.25544  38.12000  10.379780  29.58025
# 2        4040220    213    50  11.36640  41.16216   9.821616  32.56744
# 3        4040320    226    52  12.96285  39.78724   9.937702  31.00000
# 4        4040420    193    65  12.11177  49.50495  11.167350  37.10769
#
#        T1/3      Havg      Tavg       Eps
# 0  7.740685  19.64317  5.252430  0.842183
# 1  8.047920  18.43568  4.999222  0.838274
# 2  8.521933  20.55399  5.609682  0.863272
# 3  7.967224  19.74779  5.272195  0.848451
# 4  9.651505  22.15026  6.177589  0.876558

# %%
data['Time(mddhhmm)'].astype(str).str[5:7].value_counts()
# Out:
# Time(mddhhmm)
# 20    72
# Name: count, dtype: int64

# %%
data['Time(mddhhmm)'].astype(str).str[3:5].value_counts()
# Out:
# Time(mddhhmm)
# 00    3
# 01    3
# 02    3
# 03    3
# 04    3
# 05    3
# 06    3
# 07    3
# 08    3
# 09    3
# 10    3
# 11    3
# 12    3
# 13    3
# 14    3
# 15    3
# 16    3
# 17    3
# 18    3
# 19    3
# 20    3
# 21    3
# 22    3
# 23    3
# Name: count, dtype: int64

# %%
data['Time(mddhhmm)'].astype(str).str[1:3].value_counts()
# Out:
# Time(mddhhmm)
# 01    48
# 04    24
# Name: count, dtype: int64

# %%
data['Time(mddhhmm)'].astype(str).str[0].value_counts()
# Out:
# Time(mddhhmm)
# 4    48
# 6    24
# Name: count, dtype: int64

# %%
data['month'] = data['Time(mddhhmm)'].astype(str).str[0].astype(int)
data.head()
# Out:
#    Time(mddhhmm)  Waves  Hmax       Thm     H1/10      T1/10      H1/3  \
# 0        4040020    227    45  11.16264  37.99153   9.350759  30.27074
# 1        4040120    241    50  11.25544  38.12000  10.379780  29.58025
# 2        4040220    213    50  11.36640  41.16216   9.821616  32.56744
# 3        4040320    226    52  12.96285  39.78724   9.937702  31.00000
# 4        4040420    193    65  12.11177  49.50495  11.167350  37.10769
#
#        T1/3      Havg      Tavg       Eps  month
# 0  7.740685  19.64317  5.252430  0.842183      4
# 1  8.047920  18.43568  4.999222  0.838274      4
# 2  8.521933  20.55399  5.609682  0.863272      4
# 3  7.967224  19.74779  5.272195  0.848451      4
# 4  9.651505  22.15026  6.177589  0.876558      4

# %%
data['day'] = data['Time(mddhhmm)'].astype(str).str[1:3].astype(int)
data.head()
# Out:
#    Time(mddhhmm)  Waves  Hmax       Thm     H1/10      T1/10      H1/3  \
# 0        4040020    227    45  11.16264  37.99153   9.350759  30.27074
# 1        4040120    241    50  11.25544  38.12000  10.379780  29.58025
# 2        4040220    213    50  11.36640  41.16216   9.821616  32.56744
# 3        4040320    226    52  12.96285  39.78724   9.937702  31.00000
# 4        4040420    193    65  12.11177  49.50495  11.167350  37.10769
#
#        T1/3      Havg      Tavg       Eps  month  day
# 0  7.740685  19.64317  5.252430  0.842183      4    4
# 1  8.047920  18.43568  4.999222  0.838274      4    4
# 2  8.521933  20.55399  5.609682  0.863272      4    4
# 3  7.967224  19.74779  5.272195  0.848451      4    4
# 4  9.651505  22.15026  6.177589  0.876558      4    4

# %%
data['hour'] = data['Time(mddhhmm)'].astype(str).str[3:5].astype(int)
data.head()
# Out:
#    Time(mddhhmm)  Waves  Hmax       Thm     H1/10      T1/10      H1/3  \
# 0        4040020    227    45  11.16264  37.99153   9.350759  30.27074
# 1        4040120    241    50  11.25544  38.12000  10.379780  29.58025
# 2        4040220    213    50  11.36640  41.16216   9.821616  32.56744
# 3        4040320    226    52  12.96285  39.78724   9.937702  31.00000
# 4        4040420    193    65  12.11177  49.50495  11.167350  37.10769
#
#        T1/3      Havg      Tavg       Eps  month  day  hour
# 0  7.740685  19.64317  5.252430  0.842183      4    4     0
# 1  8.047920  18.43568  4.999222  0.838274      4    4     1
# 2  8.521933  20.55399  5.609682  0.863272      4    4     2
# 3  7.967224  19.74779  5.272195  0.848451      4    4     3
# 4  9.651505  22.15026  6.177589  0.876558      4    4     4

# %%
data=data.drop('Time(mddhhmm)',axis=1)
data.head()
# Out:
#    Waves  Hmax       Thm     H1/10      T1/10      H1/3      T1/3      Havg  \
# 0    227    45  11.16264  37.99153   9.350759  30.27074  7.740685  19.64317
# 1    241    50  11.25544  38.12000  10.379780  29.58025  8.047920  18.43568
# 2    213    50  11.36640  41.16216   9.821616  32.56744  8.521933  20.55399
# 3    226    52  12.96285  39.78724   9.937702  31.00000  7.967224  19.74779
# 4    193    65  12.11177  49.50495  11.167350  37.10769  9.651505  22.15026
#
#        Tavg       Eps  month  day  hour
# 0  5.252430  0.842183      4    4     0
# 1  4.999222  0.838274      4    4     1
# 2  5.609682  0.863272      4    4     2
# 3  5.272195  0.848451      4    4     3
# 4  6.177589  0.876558      4    4     4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 0 to 23
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Waves   72 non-null     int64
#  1   Hmax    72 non-null     int64
#  2   Thm     72 non-null     float64
#  3   H1/10   72 non-null     float64
#  4   T1/10   72 non-null     float64
#  5   H1/3    72 non-null     float64
#  6   T1/3    72 non-null     float64
#  7   Havg    72 non-null     float64
#  8   Tavg    72 non-null     float64
#  9   Eps     72 non-null     float64
#  10  month   72 non-null     int64
#  11  day     72 non-null     int64
#  12  hour    72 non-null     int64
# dtypes: float64(8), int64(5)
# memory usage: 9.9 KB

# %%
import seaborn as sns
sns.countplot(x='month',data=data)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
sns.countplot(x='hour',data=data)
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
sns.countplot(x='day',data=data)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data.corr()
# Out:
#           Waves      Hmax       Thm     H1/10     T1/10      H1/3      T1/3  \
# Waves  1.000000 -0.278552 -0.490194 -0.344242 -0.827482 -0.325764 -0.973362
# Hmax  -0.278552  1.000000  0.047575  0.829130  0.106942  0.751635  0.239705
# Thm   -0.490194  0.047575  1.000000  0.024110  0.655867 -0.000809  0.508539
# H1/10 -0.344242  0.829130  0.024110  1.000000  0.115447  0.964163  0.289778
# T1/10 -0.827482  0.106942  0.655867  0.115447  1.000000  0.035869  0.885704
# H1/3  -0.325764  0.751635 -0.000809  0.964163  0.035869  1.000000  0.253648
# T1/3  -0.973362  0.239705  0.508539  0.289778  0.885704  0.253648  1.000000
# Havg  -0.102982  0.647346 -0.109453  0.861116 -0.198923  0.944294  0.003711
# Tavg  -0.980771  0.312168  0.420582  0.416213  0.753540  0.411864  0.949965
# Eps   -0.856307  0.172774  0.624772  0.186164  0.909552  0.130072  0.899785
# month  0.150594  0.201578 -0.044320  0.197348 -0.249558  0.254198 -0.259441
# ...

# %%
data.corr().Havg
# Out:
# Waves   -0.102982
# Hmax     0.647346
# Thm     -0.109453
# H1/10    0.861116
# T1/10   -0.198923
# H1/3     0.944294
# T1/3     0.003711
# Havg     1.000000
# Tavg     0.200966
# Eps     -0.099498
# month    0.381578
# day     -0.402927
# hour     0.106412
# Name: Havg, dtype: float64

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
X = data.drop(['Havg'],axis=1)
y = data['Havg']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
lr.fit(X_train, y_train)
lr.score(X_train, y_train),lr.score(X_test, y_test)
# Out:
# (0.9784437634039685, 0.9864365068407916)

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([24.67370121, 22.60117619, 27.18280541, 18.89786935, 24.69813908,
#        30.06614001, 23.64127612, 25.86715439, 26.1339523 , 26.12803014,
#        31.69159673, 22.05076928, 24.7014434 , 23.55143915, 32.37290036,
#        21.80541123, 25.53925203, 25.03864003, 30.26790398, 18.01407036,
#        25.39123748, 29.57242486])

# %%
df = pd.DataFrame(list(zip(y_test, y_pred)), 
               columns =['y_test', 'y_pred']) 
df.head(10)
# Out:
#      y_test     y_pred
# 0  23.97024  24.673701
# 1  22.44586  22.601176
# 2  27.52852  27.182805
# 3  18.43568  18.897869
# 4  25.43949  24.698139
# 5  30.08469  30.066140
# 6  24.38461  23.641276
# 7  25.79574  25.867154
# 8  25.49333  26.133952
# 9  25.91282  26.128030

# %%
df['%error']=100*abs(df['y_test']-df['y_pred'])/df['y_test']
df.head(10)
# Out:
#      y_test     y_pred    %error
# 0  23.97024  24.673701  2.934727
# 1  22.44586  22.601176  0.691959
# 2  27.52852  27.182805  1.255842
# 3  18.43568  18.897869  2.507037
# 4  25.43949  24.698139  2.914174
# 5  30.08469  30.066140  0.061659
# 6  24.38461  23.641276  3.048373
# 7  25.79574  25.867154  0.276846
# 8  25.49333  26.133952  2.512902
# 9  25.91282  26.128030  0.830516
